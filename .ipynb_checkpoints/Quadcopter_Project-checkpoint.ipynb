# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-17.71306288  -6.895409    29.18952839   6.17118243   0.363776
#    0.        ]
# [-11.27998669  -4.74066434   3.5031488 ]
# [0.13623829 0.04217443 0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =  -0.712 (best =   0.089), noise_scale = 3.255

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import tensorflow as tf

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (14,8))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.scatter(results['x'], results['y'], results['z'])

# %%
from agents.agent import DDPG

agent = DDPG(task)
state = agent.reset_episode()
print(task.get_reward())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-575a770342f3> in <module>
#       1 from agents.agent import DDPG
#       2
# ----> 3 agent = DDPG(task)
#       4 state = agent.reset_episode()
#       5 print(task.get_reward())
#
# ~\OneDrive - Nerve Smart Systems ApS\Documents\GitHub\RL-Quadcopter-2\agents\agent.py in __init__(self, task)
#     172         # Actor (Policy) Model
#     173         self.actor_local = Actor(self.state_size, self.action_size,
# --> 174                                  self.action_low, self.action_high)
#     175         self.actor_target = Actor(self.state_size, self.action_size,
#     176                                   self.action_low, self.action_high)
#
# ~\OneDrive - Nerve Smart Systems ApS\Documents\GitHub\RL-Quadcopter-2\agents\agent.py in __init__(self, state_size, action_size, action_low, action_high)
#      59         # Initialize any other variables here
#      60
# ---> 61         self.build_model()
#      62
#      63     def build_model(self):
#
# ~\OneDrive - Nerve Smart Systems ApS\Documents\GitHub\RL-Quadcopter-2\agents\agent.py in build_model(self)
#      64         """Build an actor (policy) network that maps states -> actions."""
#      65         # Define input layer (states)
# ---> 66         states = layers.Input(shape=(self.state_size,), name='states')
#      67
#      68         # Add hidden layers
#
# ~\Anaconda3\envs\GK\lib\site-packages\keras\engine\input_layer.py in Input(shape, batch_shape, name, dtype, sparse, tensor)
#     176                              name=name, dtype=dtype,
#     177                              sparse=sparse,
# --> 178                              input_tensor=tensor)
#     179     # Return tensor including _keras_shape and _keras_history.
#     180     # Note that in this case train_output and test_output are the same pointer.
#
# ~\Anaconda3\envs\GK\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\envs\GK\lib\site-packages\keras\engine\input_layer.py in __init__(self, input_shape, batch_size, batch_input_shape, dtype, input_tensor, sparse, name)
#      85                                          dtype=dtype,
#      86                                          sparse=self.sparse,
# ---> 87                                          name=self.name)
#      88         else:
#      89             self.is_placeholder = False
#
# ~\Anaconda3\envs\GK\lib\site-packages\keras\backend\tensorflow_backend.py in placeholder(shape, ndim, dtype, sparse, name)
#     515         x = tf.sparse_placeholder(dtype, shape=shape, name=name)
#     516     else:
# --> 517         x = tf.placeholder(dtype, shape=shape, name=name)
#     518     x._keras_shape = shape
#     519     x._uses_learning_phase = False
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, noise = {}, reward = {}".format(
                i_episode, agent.noise.sample(), task.get_reward()), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, noise = [0.39077229 0.62258846 0.23884746 0.152528  ], reward = -19.29037304793621439054165996706440447

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
import time

class AnimatedPlot():
    def __init__(self):
        """Initialize parameters"""
        self.X, self.Y, self.Z = [], [], []

        self.fig = plt.figure(figsize = (14,8))
        self.ax = self.fig.add_subplot(111, projection='3d')

    def plot(self, task, i_episode=None):
        pose = task.sim.pose[:3]
        self.X.append(pose[0])
        self.Y.append(pose[1])
        self.Z.append(pose[2])
        self.ax.clear()
        if i_episode:
            plt.title("Episode {}".format(i_episode))

        if len(self.X)>1:
            self.ax.scatter(self.X[:-1], self.Y[:-1], self.Z[:-1], c='k', alpha=0.3)
        if task.sim.done and task.sim.runtime > task.sim.time:
            # Colision
            self.ax.scatter(pose[0], pose[1], pose[2], c='r', marker='*', linewidths=5)
            print('colision: ', pose)
        else:
            self.ax.scatter(pose[0], pose[1], pose[2], c='k', marker='s', linewidths=5)
            #print('else: ', pose)

        self.fig.canvas.draw()
        time.sleep(0.5)
# Out:
# [autoreload of tensorflow failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\multiarray.py", line 78, in <module>
#     def empty_like(prototype, dtype=None, order=None, subok=None, shape=None):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\overrides.py", line 186, in decorator
#     if module is not None:
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\overrides.py", line 150, in decorator
#     implementation.__module__ = module
# RuntimeError: empty_like method already has a docstring
# ]
# [autoreload of numpy.core.overrides failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\overrides.py", line 47, in <module>
#     """)
# RuntimeError: implement_array_function method already has a docstring
# ]
# [autoreload of numpy.core.numeric failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\numeric.py", line 12, in <module>
#     from numpy.compat import pickle, basestring
# ImportError: cannot import name 'pickle'
# ]
# [autoreload of numpy.core._methods failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\_methods.py", line 16, in <module>
#     from numpy.compat import pickle, os_fspath, contextlib_nullcontext
# ImportError: cannot import name 'pickle'
# ]
# [autoreload of numpy.core._add_newdocs failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\_add_newdocs.py", line 6839, in <module>
#     """.format(ftype=float_name)))
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\core\function_base.py", line 467, in add_newdoc
#     _add_docstring(getattr(new, doc[0]), doc[1].strip())
# AttributeError: type object 'numpy.float16' has no attribute 'as_integer_ratio'
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\lib\__init__.py", line 32, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.lib.index_tricks failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\lib\index_tricks.py", line 13, in <module>
#     import numpy.matrixlib as matrixlib
# AttributeError: module 'numpy' has no attribute 'matrixlib'
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\matrixlib\__init__.py", line 8, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\lib\scimath.py", line 21, in <module>
#     import numpy.core.numerictypes as nt
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.lib.npyio failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\lib\npyio.py", line 26, in <module>
#     from numpy.compat import (
# ImportError: cannot import name 'pickle'
# ]
# [autoreload of numpy.lib.format failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\lib\format.py", line 171, in <module>
#     from numpy.compat import (
# ImportError: cannot import name 'pickle'
# ]
# [autoreload of numpy.random failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\random\__init__.py", line 181, in <module>
#     from . import _pickle
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\random\_pickle.py", line 2, in <module>
#     from .philox import Philox
#   File "philox.pyx", line 1, in init numpy.random.philox
# TypeError: 'errstate' object is not callable
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\ma\core.py", line 39, in <module>
#     import numpy.core.numerictypes as ntypes
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.testing failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\numpy\testing\__init__.py", line 18, in <module>
#     __all__ = _private.utils.__all__ + ['TestCase', 'run_module_suite']
# NameError: name '_private' is not defined
# ]
# [autoreload of pkg_resources.extern.six failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 147, in reload
#     raise ImportError(msg.format(name), name=name)
# ImportError: module pkg_resources._vendor.six not in sys.modules
# ]
# [autoreload of pkg_resources.extern.appdirs failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 147, in reload
#     raise ImportError(msg.format(name), name=name)
# ImportError: module pkg_resources._vendor.appdirs not in sys.modules
# ]
# [autoreload of pkg_resources._vendor.packaging.__about__ failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 159, in reload
#     name=parent_name) from None
# ImportError: parent 'pkg_resources._vendor.packaging' not in sys.modules
# ]
# [autoreload of pkg_resources.extern.packaging failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 147, in reload
#     raise ImportError(msg.format(name), name=name)
# ImportError: module pkg_resources._vendor.packaging not in sys.modules
# ]
# [autoreload of pkg_resources.extern.pyparsing failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 147, in reload
#     raise ImportError(msg.format(name), name=name)
# ImportError: module pkg_resources._vendor.pyparsing not in sys.modules
# ]
# [autoreload of tensorflow_estimator failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator._api.v1.estimator failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator._api.v1.estimator.experimental failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.estimator_lib failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\estimator_lib.py", line 41, in <module>
#     from tensorflow_estimator.python.estimator.canned.rnn import RNNClassifier
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\canned\rnn.py", line 23, in <module>
#     from tensorflow.python.feature_column import dense_features
# ImportError: cannot import name 'dense_features'
# ]
# [autoreload of tensorflow_estimator.python.estimator.estimator failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py", line 2133, in <module>
#     estimator_export('estimator.VocabInfo')(VocabInfo)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 334, in __call__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 346, in set_attr
# tensorflow.python.util.tf_export.SymbolAlreadyExposedError: Symbol VocabInfo is already exposed as ('estimator.VocabInfo',).
# ]
# [autoreload of tensorflow_estimator.python.estimator.mode_keys failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\mode_keys.py", line 26, in <module>
#     estimator_export('estimator.ModeKeys')(ModeKeys)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 334, in __call__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 346, in set_attr
# tensorflow.python.util.tf_export.SymbolAlreadyExposedError: Symbol EstimatorModeKeys is already exposed as ('estimator.ModeKeys',).
# ]
# [autoreload of tensorflow_estimator.python.estimator.export.export_output failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\export\export_output.py", line 33, in <module>
#     estimator_export('estimator.export.ExportOutput')(ExportOutput)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 334, in __call__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 346, in set_attr
# tensorflow.python.util.tf_export.SymbolAlreadyExposedError: Symbol ExportOutput is already exposed as ('estimator.export.ExportOutput',).
# ]
# [autoreload of tensorflow_estimator.python.estimator.canned.boosted_trees failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\canned\boosted_trees.py", line 38, in <module>
#     from tensorflow.python.ops import control_flow_v2_toggles
# ImportError: cannot import name 'control_flow_v2_toggles'
# ]
# [autoreload of tensorflow_estimator.python.estimator.canned.dnn failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py", line 23, in <module>
#     from tensorflow.python.feature_column import dense_features
# ImportError: cannot import name 'dense_features'
# ]
# [autoreload of tensorflow_estimator.python.estimator.hooks.basic_session_run_hooks failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\hooks\basic_session_run_hooks.py", line 36, in <module>
#     estimator_export("estimator.SecondOrStepTimer")(SecondOrStepTimer)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 334, in __call__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 346, in set_attr
# tensorflow.python.util.tf_export.SymbolAlreadyExposedError: Symbol SecondOrStepTimer is already exposed as ('estimator.SecondOrStepTimer',).
# ]
# [autoreload of tensorflow_estimator.python.estimator.hooks.session_run_hook failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\hooks\session_run_hook.py", line 98, in <module>
#     estimator_export("estimator.SessionRunHook")(SessionRunHook)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 334, in __call__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\tf_export.py", line 346, in set_attr
# tensorflow.python.util.tf_export.SymbolAlreadyExposedError: Symbol SessionRunHook is already exposed as ('estimator.SessionRunHook',).
# ]
# [autoreload of tensorflow_estimator.python.estimator.tpu._tpu_estimator_embedding failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow_estimator\python\estimator\tpu\_tpu_estimator_embedding.py", line 33, in <module>
#     from tensorflow.python.tpu import feature_column_v2 as tpu_fc_v2
# ImportError: cannot import name 'feature_column_v2'
# ]
# [autoreload of tensorflow_estimator._api.v1.estimator.export failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator._api.v1.estimator.inputs failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator._api.v1.estimator.tpu failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api._v1.estimator failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api._v1.estimator.experimental failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api._v1.estimator.export failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api._v1.estimator.inputs failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]
# [autoreload of tensorflow_estimator.python.estimator.api._v1.estimator.tpu failed: Traceback (most recent call last):
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\IPython\extensions\autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\importlib\__init__.py", line 165, in reload
#     spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 128, in __setattr__
#   File "C:\Users\GK\Anaconda3\envs\GK\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py", line 105, in __getattr__
# AttributeError: Accessing local variables before they are created.
# ]

# %%
myplot = AnimatedPlot()

for i in range(10):
    state = agent.reset_episode() # start a new episode
    epsodie = 1

    target_pos = np.array([0., 0., 10.])
    task = Task(target_pos=target_pos)


    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state


        # CALL THE METHOD plot(task)
        myplot.plot(task,epsodie)
        epsodie += 1

        if done:
            break

# %%
# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act(state) 
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
